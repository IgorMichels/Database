# %%
import pandas as pd

local = 'C:/Users/igorm/Desktop/FGV/4º Semestre/07 - Banco de Dados/Csvs/'
arquivos = ['2019-01', '2019-02', '2019-03', '2019-04',
            '2019-05', '2019-06', '2019-07', '2019-08',
            '2019-09', '2019-10', '2019-11', '2019-12',
            '2020-01', '2020-02', '2020-03', '2020-04',
            '2020-05'] # lista de arquivos que temos sem o ' compressed.csv'

# %%
# juntando todos os dados num só data frame

dataframe = pd.read_csv(local + arquivos[0] + ' compressed.csv', delimiter = ';')

for arquivo in arquivos:
    if arquivo == "2019-01":
        pass
    else:
        dataframe2 = pd.read_csv(local + arquivo + ' compressed.csv', delimiter = ';')
        frames = [dataframe, dataframe2]
        dataframe = pd.concat(frames)

# %%
dataframe2 = dataframe

# %%
order = [1, 2, 11, 12, 13, 14, 15, 16, 17, 3, 4, 5, 6, 7, 8, 9, 10]
dataframe2 = dataframe2[[dataframe2.columns[i] for i in order]]
dataframe2
# Out:
#            FL_DATE TAIL_NUM  DEP_TIME  DEP_DELAY  CARRIER_DELAY  \
# 0       03/01/2019   N195PQ    1205.0       25.0            0.0
# 1       04/01/2019   N919XJ    1250.0       70.0            0.0
# 2       05/01/2019   N316PQ     956.0        6.0            NaN
# 3       06/01/2019   N325PQ     945.0       -5.0            NaN
# 4       07/01/2019   N904XJ     947.0       -3.0            NaN
# 5       08/01/2019   N917XJ     950.0        0.0            NaN
# 6       09/01/2019   N904XJ     945.0       -5.0            NaN
# 7       10/01/2019   N919XJ     943.0       -7.0            NaN
# 8       11/01/2019   N135EV     945.0       -5.0            0.0
# 9       12/01/2019   N302PQ     949.0       -1.0            NaN
# 10      13/01/2019   N925XJ     947.0       -3.0            NaN
# 11      14/01/2019   N932XJ     951.0        1.0            NaN
# 12      15/01/2019   N917XJ    1043.0       53.0           11.0
# 13      16/01/2019   N329PQ     945.0       -5.0            NaN
# ...

# %%
routes_long = dataframe2.iloc[:, 9:]
routes_long
# Out:
#        ORIGIN   ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM DEST  \
# 0         TYS      Knoxville, TN               TN       Tennessee  ATL
# 1         TYS      Knoxville, TN               TN       Tennessee  ATL
# 2         ATL        Atlanta, GA               GA         Georgia  SGF
# 3         ATL        Atlanta, GA               GA         Georgia  SGF
# 4         ATL        Atlanta, GA               GA         Georgia  SGF
# 5         ATL        Atlanta, GA               GA         Georgia  SGF
# 6         ATL        Atlanta, GA               GA         Georgia  SGF
# 7         ATL        Atlanta, GA               GA         Georgia  SGF
# 8         ATL        Atlanta, GA               GA         Georgia  SGF
# 9         ATL        Atlanta, GA               GA         Georgia  SGF
# 10        ATL        Atlanta, GA               GA         Georgia  SGF
# 11        ATL        Atlanta, GA               GA         Georgia  SGF
# ...

# %%
order = [0, 4]
routes = routes_long[[routes_long.columns[i] for i in order]]
routes.drop_duplicates(inplace = True)
routes.reset_index(inplace = True)
routes.drop('index', 1, inplace = True)
routes.to_csv('C:/Users/igorm/Desktop/FGV/4º Semestre/07 - Banco de Dados/Database/scraping/routes.csv', sep = ';')
# Out:
# C:\Users\igorm\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
routes_long.drop_duplicates(inplace = True)
routes_long.reset_index(inplace = True)
routes_long.drop('index', 1, inplace = True)
routes_long.to_csv('C:/Users/igorm/Desktop/FGV/4º Semestre/07 - Banco de Dados/Database/scraping/airports.csv', sep = ';')
