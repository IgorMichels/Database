# %%
import pandas as pd
import numpy as np

local = 'C:/Users/igorm/Desktop/FGV/4º Semestre/07 - Banco de Dados/Csvs/'
novo_local = 'C:/Users/igorm/Desktop/FGV/4º Semestre/07 - Banco de Dados/'
arquivos = ['2019-01', '2019-02', '2019-03', '2019-04',
            '2019-05', '2019-06', '2019-07', '2019-08',
            '2019-09', '2019-10', '2019-11', '2019-12',
            '2020-01', '2020-02', '2020-03', '2020-04',
            '2020-05'] # lista de arquivos que temos sem o ' compressed.csv'

# %%
dataframe = pd.read_csv(local + arquivos[10] + ' compressed.csv', delimiter = ';')

# %%
order = [1, 2, 11, 12, 13, 14, 15, 16, 17, 18, 3, 4, 5, 6, 7, 8, 9, 10]
dataframe = dataframe[[dataframe.columns[i] for i in order]]
dataframe
# Out:
#            FL_DATE TAIL_NUM  DEP_TIME  DEP_DELAY  ARR_TIME  CARRIER_DELAY  \
# 0       23/11/2019   N220WN    1457.0       -8.0    1710.0            NaN
# 1       23/11/2019   N490WN    2121.0       -9.0    2335.0            NaN
# 2       23/11/2019   N489WN    1908.0       -7.0    2104.0            NaN
# 3       23/11/2019   N8692F    1400.0       -5.0    1619.0            NaN
# 4       23/11/2019   N8314L    2031.0       -4.0    2256.0            NaN
# 5       23/11/2019   N7836A     830.0       10.0    1049.0            NaN
# 6       23/11/2019   N922WN    1657.0       -3.0    1916.0            NaN
# 7       23/11/2019   N8615E     627.0       -3.0     822.0            NaN
# 8       23/11/2019   N278WN    1050.0       45.0    1238.0           32.0
# 9       23/11/2019   N495WN    1451.0       -9.0    1630.0            NaN
# 10      23/11/2019   N7875A    2208.0       -2.0       3.0            NaN
# 11      23/11/2019   N7881A     614.0       -1.0     758.0            NaN
# ...

# %%
delay = dataframe.iloc[:, :10]
delay
# Out:
#            FL_DATE TAIL_NUM  DEP_TIME  DEP_DELAY  ARR_TIME  CARRIER_DELAY  \
# 0       23/11/2019   N220WN    1457.0       -8.0    1710.0            NaN
# 1       23/11/2019   N490WN    2121.0       -9.0    2335.0            NaN
# 2       23/11/2019   N489WN    1908.0       -7.0    2104.0            NaN
# 3       23/11/2019   N8692F    1400.0       -5.0    1619.0            NaN
# 4       23/11/2019   N8314L    2031.0       -4.0    2256.0            NaN
# 5       23/11/2019   N7836A     830.0       10.0    1049.0            NaN
# 6       23/11/2019   N922WN    1657.0       -3.0    1916.0            NaN
# 7       23/11/2019   N8615E     627.0       -3.0     822.0            NaN
# 8       23/11/2019   N278WN    1050.0       45.0    1238.0           32.0
# 9       23/11/2019   N495WN    1451.0       -9.0    1630.0            NaN
# 10      23/11/2019   N7875A    2208.0       -2.0       3.0            NaN
# 11      23/11/2019   N7881A     614.0       -1.0     758.0            NaN
# ...

# %%
column_names = ["delay_cause"]
delay_cause = pd.DataFrame(columns = column_names)

line = 0
for i in delay['DEP_DELAY']:
    if i <= 0 or np.isnan(i):
        new_row = {'delay_cause' : ''}
    else:
        if np.isnan(delay['CARRIER_DELAY'][line]):
            maior = 0
            k = ""
        else:
            maior = delay['CARRIER_DELAY'][line]
            k = 1
        if np.isnan(delay['WEATHER_DELAY'][line]) == False and maior < delay['WEATHER_DELAY'][line]:
            k = 2
            maior = delay['WEATHER_DELAY'][line]
        if np.isnan(delay['NAS_DELAY'][line]) == False and maior < delay['NAS_DELAY'][line]:
            k = 3
            maior = delay['NAS_DELAY'][line]
        if np.isnan(delay['SECURITY_DELAY'][line]) == False and maior < delay['SECURITY_DELAY'][line]:
            k = 4
            maior = delay['SECURITY_DELAY'][line]
        if np.isnan(delay['LATE_AIRCRAFT_DELAY'][line]) == False and maior < delay['LATE_AIRCRAFT_DELAY'][line]:
            k = 5
            maior = delay['LATE_AIRCRAFT_DELAY'][line]
        new_row = {'delay_cause' : k}
    line += 1
    if line % 1000 == 0:
        print(line)
    delay_cause = delay_cause.append(new_row, ignore_index = True)
    
delay_cause
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# ...

# %%
frames = [dataframe, delay_cause]
df = pd.concat(frames, axis = 1)
df
# Out:
#            FL_DATE TAIL_NUM  DEP_TIME  DEP_DELAY  ARR_TIME  CARRIER_DELAY  \
# 0       23/11/2019   N220WN    1457.0       -8.0    1710.0            NaN
# 1       23/11/2019   N490WN    2121.0       -9.0    2335.0            NaN
# 2       23/11/2019   N489WN    1908.0       -7.0    2104.0            NaN
# 3       23/11/2019   N8692F    1400.0       -5.0    1619.0            NaN
# 4       23/11/2019   N8314L    2031.0       -4.0    2256.0            NaN
# 5       23/11/2019   N7836A     830.0       10.0    1049.0            NaN
# 6       23/11/2019   N922WN    1657.0       -3.0    1916.0            NaN
# 7       23/11/2019   N8615E     627.0       -3.0     822.0            NaN
# 8       23/11/2019   N278WN    1050.0       45.0    1238.0           32.0
# 9       23/11/2019   N495WN    1451.0       -9.0    1630.0            NaN
# 10      23/11/2019   N7875A    2208.0       -2.0       3.0            NaN
# 11      23/11/2019   N7881A     614.0       -1.0     758.0            NaN
# ...

# %%
df.drop('ORIGIN_CITY_NAME', 1, inplace = True)
df.drop('ORIGIN_STATE_ABR', 1, inplace = True)
df.drop('ORIGIN_STATE_NM', 1, inplace = True)
df.drop('DEST_CITY_NAME', 1, inplace = True)
df.drop('DEST_STATE_ABR', 1, inplace = True)
df.drop('DEST_STATE_NM', 1, inplace = True)
df.drop('LATE_AIRCRAFT_DELAY', 1, inplace = True)
df.drop('WEATHER_DELAY', 1, inplace = True)
df.drop('NAS_DELAY', 1, inplace = True)
df.drop('SECURITY_DELAY', 1, inplace = True)
df.drop('CARRIER_DELAY', 1, inplace = True)
df.to_csv(local + '2019-11 - final.csv', sep = ';')
